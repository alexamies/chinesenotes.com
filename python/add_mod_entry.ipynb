# %% [markdown]
# # Notebook to add dictionary entries

# %%
import re
import pandas as pd
import numpy as np

# Load lexical units table
colnames = ['id', 'simplified', 'traditional', 'pinyin', 
            'english', 'grammar', 'concept_cn', 'concept_en', 
            'domain_cn', 'domain_en', 'subdomain_cn', 'subdomain_en',
            'image', 'mp3', 'notes', 'headword']
types = {'id': np.uint32, 'simplified': np.object, 'traditional': np.object, 
        'pinyin': np.object, 'english': np.object, 'grammar': np.object,
        'concept_cn': np.object, 'concept_en': np.object,
        'domain_cn': np.object, 'domain_en': np.object, 'subdomain_cn': np.object,
         'subdomain_en': np.object, 'image': np.object, 'mp3': np.object,
         'notes': np.object, 'headword': np.uint32}
df = pd.read_table('../../buddhist-dictionary/data/dictionary/words.txt', names=colnames, dtype=types)
# Words with no notes
df.ix[df.notes == '\N'][:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-dd508f86db95> in <module>()
#      14          'subdomain_en': np.object, 'image': np.object, 'mp3': np.object,
#      15          'notes': np.object, 'headword': np.uint32}
# ---> 16 df = pd.read_table('../../buddhist-dictionary/data/dictionary/words.txt', names=colnames, dtype=types)
#      17 # Words with no notes
#      18 df.ix[df.notes == '\N'][:5]
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     323         return parser
#     324
# --> 325     return parser.read()
#     326
#     327 _parser_defaults = {
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     813                 raise ValueError('skip_footer not supported for iteration')
#     814
# --> 815         ret = self._engine.read(nrows)
#     816
#     817         if self.options.get('as_recarray'):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1312     def read(self, nrows=None):
#    1313         try:
# -> 1314             data = self._reader.read(nrows)
#    1315         except StopIteration:
#    1316             if self._first_chunk:
#
# pandas/parser.pyx in pandas.parser.TextReader.read (pandas/parser.c:8748)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_low_memory (pandas/parser.c:9003)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_rows (pandas/parser.c:10022)()
#
# pandas/parser.pyx in pandas.parser.TextReader._convert_column_data (pandas/parser.c:11397)()
#
# pandas/parser.pyx in pandas.parser.TextReader._convert_tokens (pandas/parser.c:12775)()
#
# ValueError: cannot safely convert passed user dtype of <u4 for object dtyped data in column 0

# %%
#Add a new entry
# Find simplified and pinyin from a traditional text string

#Input
tradArr = ["五", "子", "登", "科"]
english = [u"to chase material things in life"]
grammar = ["set phrase"]
# Concept
empty = u"\\N\t\\N"
animal = u"动物\tAnimal"
association = u"协会\tAssociation"
bird = u"鸟\tBird"
book = u"书名\tBook Title"
city = u"城市\tCity"
cl = "类\tClass"
color = u"颜色\tColor"
company = u"公司\tCompany"
compound = u"化合物\tCompound"
county = u"县\tCounty"
country = u"国家\tCountry"
deity = u"神\tDeity"
discipline = u"学科\tDiscipline"
district = u"地区\tDistrict"
dynasty = u"朝代\tDynasty"
emperor = u"黄帝\tEmperor"
epoch = u"世\tEpoch"
family = u"科\tFamily"
festival = u"节日\tFestival"
flower = u"花\tFlower"
fruit = u"水果\tFruit"
genus = u"属\tGenus"
geo_period = u"地质年代\tGeological Period"
given = u"姓名\tGiven Name"
heaven = u"天\tHeaven"
industry = u"产业\tIndustry"
insect = u"昆虫\tInsect"
island = u"岛\tIsland"
kingdom = u"王国\tKingdom"
lake = u"湖\tLake"
language_family = u"语系\tLanguage Family"
language = u"语言\tLanguage"
library = u"图书馆\tLibrary"
monarch = u"君主\tMonarch"
monastic = u"法师\tMonastic"
mountain = u"山\tMountain"
mountain_range = u"山脉\tMountain Range"
movie = u"电影\tMovie"
newspaper = u"报纸\tNewspaper"
np = u"国家公园\tNational Park"
order = u"目\tOrder"
organization = u"团体\tOrganization"
peak = u"峰\tPeak"
person = u"人\tPerson"
place = u"地名\tPlace Name"
plant = u"植物\tPlant"
province = u"省\tProvince"
publisher = u"出版者\tPublisher"
reign = u"年号\tReign Name"
river = u"水名\tRiver"
scholar = u"学者\tScholar"
school = u"宗\tSchool"
scientist = u"科学家\tScientist"
sect = u"派别\tSect"
spice = u"调料\tSpice"
state = u"州\tState"
subphylum = u"亚门\tSubphylum"
surname = u"姓氏\tSurname"
temple = u"寺院\tTemple"
tian = u"天\tDeity"
title = u"官名\tOfficial Title"
tree = u"树\tTree"
vegetable = u"蔬菜\tVegetable"
university = u"大学\tUniversity"
writer = u"作者\tAuthor"
concept = [empty]

# Domain
admin = u"管理\tAdministration"
agriculture = u"农业\tAgriculture"
anthropology = u"人类学\tAnthropology"
architecture = u"建筑学\tArchitecture"
art = u"艺术\tArt"
astronomy = u"天文\tAstronomy"
astrology = u"占星术\tAstrology"
aviation = u"航空\tAviation"
biology = u"生物学\tBiology"
botany = u"植物学\tBotany"
buddhism = u"佛教\tBuddhism"
calligraphy = u"书法\tCalligraphy"
chemistry = u"化学\tChemistry"
chinese_med = u"中医\tChinese Medicine"
christianity = u"基督教\tChristianity"
civil = u"土木\tCivil Engineering"
classical = u"古文\tClassical Chinese"
clothing = u"服装\tClothing"
commerce = u"商务\tCommerce"
common = u"俗语\tCommon Saying"
communication = u"通讯\tCommunications"
comparison = u"比较\tComparison"
compsci = u"计算机学\tComputer Science"
confucian = u"儒家\tConfucianism"
custom = u"习俗\tCustoms"
dance = u"跳舞\tDancing"
dialect = u"方言\tDialect"
disaster = u"灾难\tDisaster"
drama = u"戏剧\tDrama"
earth_sci = u"地球科学\tEarth Sciences"
econ = u"经济\tEconomics"
education = u"教育\tEducation"
ee = u"电机工程学\tElectrical Engineering"
electronics = u"电子\tElectronics"
environment = u"环境\tEnvironment"
finance = u"财会\tFinance and Accounting"
fire = u"火\tFire"
food = u"饮食\tFood and Drink"
geography = u"地理\tGeography"
geology = u"地质\tGeology"
gov = u"政府	Government"
health = u"健康\tHealth"
help = u"帮助\tHelp"
history = u"历史\tHistory"
idiom = u"成语\tIdiom"
industry = u"产业\tIndustry"
info_science = u"信息学\tInformation Science"
jewelry = u"配饰\tJewelry"
law = u"法律\tLaw"
light = u"光纤\tLight"
linguistics = u"语言学\tLinguistics"
literature = u"文学\tLiterature"
magic = u"法术\tMagic"
manufacturing = u"制造业\tManufacturing"
maritime = u"海上\tMaritime"
martial_arts  =u"武术\tMartial Arts"
materials = u"材料科学\tMaterials Science"
math = u"数学\tMathematics"
magic = u"法术\tMagic"
measurement = u"测控\tMeasurement and Control"
mechanical = u"机械\tMechanical"
media = u"媒体\tMedia"
medicine = u"医疗\tMedicine"
military = u"军事\tMilitary"
modern = u"现代汉语\tModern Chinese"
music = u"音乐\tMusic"
mythology = u"神话\tMythology"
names = u"名字\tNames"
optics = u"光学\tOptics"
organization = u"组织\tOrganization"
performing = u"表演艺术 Performing Arts"
philosophy = u"哲学\tPhilosophy"
photo = u"摄影术\tPhotography"
physics = u"物理\tPhysics"
places = u"地方\tPlaces"
poetry = u"诗\tPoetry"
politics = u"政治\tPolitics"
proverb = u"谚语\tProverb"
psychology = u"心理学\tPsychology"
public_safety = u"公安\tPublic Security"
publishing = u"出版\tPublishing"
quantity = u"数量\tQuantity"
research = u"研究\tResearch"
religion = u"宗教\tReligion"
scale = u"规模\tScale"
science = u"科学\tScience"
social = u"社会学\tSocial Science"
sound = u"声\tSound"
space = u"航天\tSpace Flight"
sport = u"体育\tSport"
spoken = u"口语\tSpoken Language"
taoism = u"道教\tTaoism"
tech = u"技术\tTechnology"
tools = u"工具\tTools"
violence = u"暴力\tViolence"
weapons = u"武器\tWeapons"
zoolology = u"动物学\tZoology"
domain = [idiom]

subdomain = u"\\N\t\\N"
#subdomain = u"能力\tAbility"
#subdomain = u"行为\tActions"
#subdomain = u"澳大利亚\tAustralia"
#subdomain = u"美丽\tBeauty"
#subdomain = u"禅宗\tChan"
#subdomain = u"变化\tChange"
#subdomain = u"特点\tCharacteristic"
#subdomain = u"中国\tChina"
#subdomain = u"基督教\tChristianity"
#subdomain = u"颜色\tColor"
#subdomain = u"比较\tComparison"
#subdomain = u"计算机图形\tComputer Graphics"
#subdomain = u"状况\tCondition"
#subdomain = u"骗局\tConfidence Trick"
#subdomain = u"冲突\tConflict"
#subdomain=u"容器\tContainer"
#subdomain = u"文化\tCulture"
#subdomain = u"死亡\tDeath"
#subdomain = u"树木学\tDendrology"
#subdomain = u"教育\tEducation"
#subdomain = u"电器\tElectrical Appliances"
#subdomain = u"电\tElectricity"
#subdomain = u"电子工程\tElectronic Engineering"
#subdomain = u"感情\tEmotion"
#subdomain = u"昆虫学\tEntomology"
#subdomain = u"家\tFamily"
#subdomain = u"形态\tForm"
#subdomain = u"友谊\tFriendship"
#subdomain = u"虚词\tFunction Words"
#subdomain = u"几何\tGeometry"
#subdomain = u"语法\tGrammar"
#subdomain = u"住房\tHousing"
#subdomain = u"幽默\tHumor"
#subdomain = u"卫生\tHygiene"
#subdomain = u"印度\tIndia"
#subdomain = u"信息\tInformation"
#subdomain = u"日本\tJapan"
#subdomain = u"语言\tLanguage"
#subdomain = u"休闲\tLeisure"
#subdomain = u"图书馆学\tLibrary Science"
#subdomain = u"生活\tLife"
#subdomain = u"力学\tMechanics"
#subdomain = u"道德\tMorality"
#subdomain = u"活动\tMovement"
#subdomain = u"大自然\tNature"
#subdomain = u"网络\tNetworking"
#subdomain = u"观察\tObservation"
#subdomain = u"有机化学\tOrganic Chemistry"
#subdomain = u"鸟类学\tOrnithology"
#subdomain = u"人\tPeople"
#subdomain = u"位\tPosition"
#subdomain = u"过程\tProcess"
#subdomain = u"语音学\tPhonetics"
#subdomain = u"数量\tQuantity"
#subdomain = u"气味\tSmell"
#subdomain = u"交际\tSocial Interaction"
#subdomain = u"社会\tSociety"
#subdomain = u"宋\tSong"
#subdomain = u"文具\tStationery"
#subdomain = u"统计学\tStatistics"
#subdomain = u"力气\tStrength"
#subdomain = u"唐\tTang"
#subdomain = u"交通\tTransportation"
#subdomain = u"温度\tTemperature"
#subdomain = u"思想\tThought"
#subdomain = u"时间\tTime"
#subdomain = u"美国\tUnited States"
#subdomain = u"水\tWater"
#subdomain = u"财富\tWealth"
#subdomain = u"写作\tWriting"
#subdomain = u"工作\tWork"
note = [u""
       ]

# Generated
luid = df.count()[0] + 1 #np.amax(df.index.values)[0] + 1
print luid
headword = luid
traditional = ""
simplified = ""
pinyin = ""
for t in tradArr:
  sDF = df[df.traditional == t]['simplified']
  tDF = df[df.traditional == t]['traditional']
  pDF = df[df.traditional == t]['pinyin']
  if sDF.count() > 0:
    simplified += sDF.iloc[0].decode('utf-8')
    traditional +=tDF.iloc[0].decode('utf-8')
    pinyin += pDF.iloc[0].decode('utf-8') + " "
  else:
    sDF = df[df.simplified == t]['simplified']
    tDF = df[df.simplified == t]['simplified']
    pDF = df[df.simplified == t]['pinyin']
    if sDF.count() > 0:
      simplified += sDF.iloc[0].decode('utf-8')
      traditional += sDF.iloc[0].decode('utf-8')
      pinyin += pDF.iloc[0].decode('utf-8') + " "
    else:
      print "%s not found" % t
pinyin.strip()
trad = traditional
if simplified == traditional:
  trad = "\\N"
pinyin = pinyin.replace(" ", "")
print simplified
print trad
print pinyin
print "English: %d" % len(english)
print "Grammar: %d" % len(grammar)
print "Concept: %d" % len(concept)
print "Domain: %d" % len(domain)
print "Note: %d" % len(note)
# Out:
# 90020
# 五子登科
# \N
# wǔzǐdēngkē
# English: 1
# Grammar: 1
# Concept: 1
# Domain: 1
# Note: 1

# %%
# Input - 
#pinyin = u"tài" # override for variant pronounciations

# Modify references as needed
# Repeat this for each lexical unit. See abbreviations.html for the abbreviations.
#bscd = u"BCSD '%s'" % traditional
aat = u"AAT '%s'" % english[0]
abc1 = u"ABC '%s' %s 1" % (pinyin, simplified)
abc2 = u"ABC '%s' %s 2" % (pinyin, simplified)
bl = u"BL '%s'" % pinyin
bcsd = u"BCSD '%s'" % traditional
bar = u"BAR '%s'" % english[0]
bussmann = u"BUS '%s'" % english[0]
cbd = u"CBD '%s'" % english[0]
ccd1 = u"CCD '%s'" % simplified
ccd2 = u"CCD '%s' 2" % simplified
cci = u"CCI p. 43"
ced1 = u"CED '%s' 1" % simplified
cedb = u"CEDB '%s'" % simplified
cedict = u"CC-CEDICT '%s'" % traditional
custom = u"T 1666"
dcp = u"DCP 'Z137'"
ecdi = u"ECDI '%s'" % english[0]
fe1 = u"FE '%s'" % traditional
fe2 = u"FE '%s' 2" % traditional
fgdb = u"FGDB '%s'" % traditional
ghc1 = u"GHC '%s'" % simplified
ghc2 = u"GHC '%s' 2" % simplified
ghc3 = u"GHC '%s' 3" % simplified
#gced = u"GCED '%s'" % traditional[0]
ghdc1 = u"GHDC '%s'" % simplified
glsib = u"GLSIB, p. 114"
guoyu = u"Guoyu '%s'" % traditional
hsk1 = u"GHDC '%s' 3" % simplified
jebd = u"JEBD '%s'" % english[0]
k1 = u"Kroll '%s'" % traditional
mhy = u"Master Hsing Yun Collected Works 《星雲大師文集》, <a href='http://www.masterhsingyun.org/article/articlelist.jsp'>www.masterhsingyun.org</a>, accessed 7 February 2017"
mw = "MW '%s'" % english[0]
ncced1 = u"NCCED '%s'" % simplified
ncced2 = u"NCCED '%s' 2" % simplified
ncced3 = u"NCCED '%s' 3" % simplified
ncced4 = u"NCCED '%s' 4" % simplified
seekers = u"SEEKERS '%s'" % english
soothill = u"SH '%s'" % traditional
sun = "Sun 2006, loc. 1582"
tan = "Tan 1996, pp. 29-30"
tgn = "TGN ID: 8201340"
wiki = "Wikipedia '%s'" % simplified
worldcat = "Worldcat Identities '%s'" % simplified
yixing = u"Yixing"
# add more references as needed
refArr = [[cedict, guoyu, wiki]]

# Print entries to standard out
for i in range(len(english)):
  luid = headword + i
  ref = u""
  for r in refArr[i]:
    if r != "":
      ref += r + "; "
  ref = re.sub("; $", "", ref)
  if ref != "":
    ref = u"(%s)" % ref

  notes = u"%s%s" % (note[i], ref)
  print u"%d\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t\\N\t\\N\t%s\t%d" % (
      luid, simplified, trad, pinyin, english[i], grammar[i], 
      concept[i], domain[i], subdomain, notes, headword)
# Out:
# 90020	五子登科	\N	wǔzǐdēngkē	to chase material things in life	set phrase	\N	\N	成语	Idiom	\N	\N	\N	\N	(CC-CEDICT '五子登科'; Guoyu '五子登科'; Wikipedia '五子登科')	90020
